# %% [markdown]
# # Lab 14 : Data Visualization

# %% [markdown]
# ## part 1 : "tips" dataset

# %% [markdown]
# ## Date : 3/9/2020

# %% [markdown]
# ### Osama-Yousef

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set()

# %%
tips = sns.load_dataset('tips')

# %%
tips.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ### we want to compare total bill VS tip

# %%
sns.relplot(x='tip', y='total_bill', hue=tips.tip.tolist(), data=tips);

# %%
tip_sums = tips.groupby('tip', as_index=False).sum()
tip_mean = tips.groupby('tip', as_index=False).mean()
tip_sums
# Out:
#        tip  total_bill  size
# 0     1.00       28.67     6
# 1     1.01       16.99     2
# 2     1.10       12.90     2
# 3     1.17       32.83     2
# 4     1.25       29.09     6
# ..     ...         ...   ...
# 118   6.70       34.30     6
# 119   6.73       48.27     4
# 120   7.58       39.42     4
# 121   9.00       48.33     4
# 122  10.00       50.81     3
#
# [123 rows x 3 columns]

# %%
tip_mean
# Out:
#        tip  total_bill  size
# 0     1.00    7.167500   1.5
# 1     1.01   16.990000   2.0
# 2     1.10   12.900000   2.0
# 3     1.17   32.830000   2.0
# 4     1.25    9.696667   2.0
# ..     ...         ...   ...
# 118   6.70   34.300000   6.0
# 119   6.73   48.270000   4.0
# 120   7.58   39.420000   4.0
# 121   9.00   48.330000   4.0
# 122  10.00   50.810000   3.0
#
# [123 rows x 3 columns]

# %%
sns.relplot(x='tip', y='total_bill',hue=tip_sums.tip.tolist(), data=tip_sums);

# %%
sns.relplot(x='tip', y='total_bill',hue=tip_mean.tip.tolist(), data=tip_mean);

# %% [markdown]
# #### now we will plot in other ways ( to try something new )

# %%
sns.lmplot(x='tip', y='total_bill', data=tip_sums);

# %%
sns.lmplot(x='tip', y='total_bill', data=tip_mean);

# %%
graph = sns.barplot(x='tip', y='total_bill', data=tip_mean,ci=None);
graph.set_xticklabels(labels=list("")[1:]);

# %%
sns.relplot(x='tip', y='total_bill',hue=tip_mean.tip.tolist(), data=tip_mean);

# %% [markdown]
# #### if we want to compare tip VS day

# %%
tips_day = tips.groupby('day', as_index=False).sum()
tips_day
# Out:
#     day  total_bill     tip  size
# 0  Thur     1096.33  171.83   152
# 1   Fri      325.88   51.96    40
# 2   Sat     1778.40  260.40   219
# 3   Sun     1627.16  247.39   216

# %%
sns.barplot(x='day', y='tip', data=tips_day);

# %% [markdown]
# ### Conclusions

# %% [markdown]
# * we learned how to use seaborn to visulaize the dataset in different ways
# * depending on the graphs above , we noticed that alomost men pay tips more than females ,another thing is that people have dinners more at the weekend time and for sure thw tips in these days more than any days in whole week
