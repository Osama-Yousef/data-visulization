# %% [markdown]
# # Lab 14 : Data Visualization

# %% [markdown]
# ## part 2 : "car_crashes" dataset

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set()

# %%
car = sns.load_dataset('car_crashes')
car.head(5)
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA

# %% [markdown]
# ### we will compare alchohol VS total because when one increase , the other will increase too
# ### so lets see this relationship relying on graphs ans some plots to see the effects of alcohol on the total

# %%
sns.relplot(x='alcohol', y='total', hue=car.alcohol.tolist(), data=car);

# %%
car_sums = car.groupby('alcohol', as_index=False).sum()
car_sums
# Out:
#     alcohol  total  speeding  not_distracted  no_previous  ins_premium  \
# 0     1.593    5.9     2.006           5.900        5.900      1273.89
# 1     1.808   11.3     4.859           9.944       10.848       809.38
# 2     2.784    9.6     2.208           8.448        8.448       777.18
# 3     2.870    8.2     1.886           7.134        6.560      1011.14
# 4     3.136   11.2     1.792           9.632        8.736      1301.52
# 5     3.328   12.8     4.224           8.576       11.520       804.71
# 6     3.360   12.0     4.200          10.920       10.680       878.41
# 7     3.429   12.7     2.413          11.049       11.176       768.95
# 8     3.480   11.6     4.060          10.092        9.628       746.54
# 9     3.498   10.6     4.452           8.692        9.116       890.03
# 10    3.567   12.3     3.936          10.824        9.840      1234.31
# 11    3.808   13.6     5.032          10.744       12.920       835.50
# ...

# %%
car_mean = car.groupby('alcohol', as_index=False).mean()
car_mean
# Out:
#     alcohol  total  speeding  not_distracted  no_previous  ins_premium  \
# 0     1.593    5.9     2.006           5.900        5.900     1273.890
# 1     1.808   11.3     4.859           9.944       10.848      809.380
# 2     2.784    9.6     2.208           8.448        8.448      777.180
# 3     2.870    8.2     1.886           7.134        6.560     1011.140
# 4     3.136   11.2     1.792           9.632        8.736     1301.520
# 5     3.328   12.8     4.224           8.576       11.520      804.710
# 6     3.360   12.0     4.200          10.920       10.680      878.410
# 7     3.429   12.7     2.413          11.049       11.176      768.950
# 8     3.480   11.6     4.060          10.092        9.628      746.540
# 9     3.498   10.6     4.452           8.692        9.116      890.030
# 10    3.567   12.3     3.936          10.824        9.840     1234.310
# 11    3.808   13.6     5.032          10.744       12.920      835.500
# ...

# %%
sns.lmplot(x='alcohol', y='total', data=car_sums);

# %%
sns.lmplot(x='alcohol', y='total', data=car_mean);

# %% [markdown]
# ### lets try doing some barplot drawing

# %%
graph = sns.barplot(x='alcohol', y='total', data=car,ci=None);

graph.set_xticklabels(labels=list("")[1:]);

# %%
graph = sns.barplot(x='alcohol', y='total', data=car_mean,ci=None);

graph.set_xticklabels(labels=list("")[1:]);

# %%
graph = sns.barplot(x='alcohol', y='total', data=car_sums,ci=None);

graph.set_xticklabels(labels=list("")[1:]);

# %% [markdown]
# ### Conclusions

# %% [markdown]
# * we learned how to use seaborn to visulaize the dataset in different ways ,scatter , bars, etc...
# * depending on the graphs above , we noticed that how much alcohol affects the total especially when the drunk people drive their vechcles and go so fast so this is dangerous situation
